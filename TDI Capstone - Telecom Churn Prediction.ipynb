# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib
import seaborn as sns

# %%
df = pd.read_csv("Telecom_customer churn_100.csv")

# %%
df.head()
# Out:
#    rev_Mean  mou_Mean  totmrc_Mean  da_Mean  ovrmou_Mean  ovrrev_Mean  \
# 0   23.9975    219.25       22.500   0.2475         0.00          0.0
# 1   57.4925    482.75       37.425   0.2475        22.75          9.1
# 2   16.9900     10.25       16.990   0.0000         0.00          0.0
# 3   38.0000      7.50       38.000   0.0000         0.00          0.0
# 4   55.2300    570.50       71.980   0.0000         0.00          0.0
#
#    vceovr_Mean  datovr_Mean  roam_Mean  change_mou  ...  forgntvl  ethnic  \
# 0          0.0          0.0        0.0     -157.25  ...       0.0       N
# 1          9.1          0.0        0.0      532.25  ...       0.0       Z
# 2          0.0          0.0        0.0       -4.25  ...       0.0       N
# 3          0.0          0.0        0.0       -1.50  ...       0.0       U
# 4          0.0          0.0        0.0       38.50  ...       0.0       I
#
#    kid0_2  kid3_5  kid6_10  kid11_15  kid16_17  creditcd  eqpdays  Customer_ID
# 0       U       U        U         U         U         Y    361.0      1000001
# 1       U       U        U         U         U         Y    240.0      1000002
# 2       U       Y        U         U         U         Y   1504.0      1000003
# 3       Y       U        U         U         U         Y   1812.0      1000004
# 4       U       U        U         U         U         Y    434.0      1000005
#
# [5 rows x 100 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 100 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   rev_Mean          99643 non-null   float64
#  1   mou_Mean          99643 non-null   float64
#  2   totmrc_Mean       99643 non-null   float64
#  3   da_Mean           99643 non-null   float64
#  4   ovrmou_Mean       99643 non-null   float64
#  5   ovrrev_Mean       99643 non-null   float64
#  6   vceovr_Mean       99643 non-null   float64
#  7   datovr_Mean       99643 non-null   float64
#  8   roam_Mean         99643 non-null   float64
#  9   change_mou        99109 non-null   float64
#  10  change_rev        99109 non-null   float64
#  11  drop_vce_Mean     100000 non-null  float64
#  12  drop_dat_Mean     100000 non-null  float64
#  13  blck_vce_Mean     100000 non-null  float64
#  14  blck_dat_Mean     100000 non-null  float64
#  15  unan_vce_Mean     100000 non-null  float64
#  16  unan_dat_Mean     100000 non-null  float64
#  17  plcd_vce_Mean     100000 non-null  float64
#  18  plcd_dat_Mean     100000 non-null  float64
#  19  recv_vce_Mean     100000 non-null  float64
#  20  recv_sms_Mean     100000 non-null  float64
#  21  comp_vce_Mean     100000 non-null  float64
#  22  comp_dat_Mean     100000 non-null  float64
#  23  custcare_Mean     100000 non-null  float64
#  24  ccrndmou_Mean     100000 non-null  float64
#  25  cc_mou_Mean       100000 non-null  float64
#  26  inonemin_Mean     100000 non-null  float64
#  27  threeway_Mean     100000 non-null  float64
#  28  mou_cvce_Mean     100000 non-null  float64
#  29  mou_cdat_Mean     100000 non-null  float64
#  30  mou_rvce_Mean     100000 non-null  float64
#  31  owylis_vce_Mean   100000 non-null  float64
#  32  mouowylisv_Mean   100000 non-null  float64
#  33  iwylis_vce_Mean   100000 non-null  float64
#  34  mouiwylisv_Mean   100000 non-null  float64
#  35  peak_vce_Mean     100000 non-null  float64
#  36  peak_dat_Mean     100000 non-null  float64
#  37  mou_peav_Mean     100000 non-null  float64
#  38  mou_pead_Mean     100000 non-null  float64
#  39  opk_vce_Mean      100000 non-null  float64
#  40  opk_dat_Mean      100000 non-null  float64
#  41  mou_opkv_Mean     100000 non-null  float64
#  42  mou_opkd_Mean     100000 non-null  float64
#  43  drop_blk_Mean     100000 non-null  float64
#  44  attempt_Mean      100000 non-null  float64
#  45  complete_Mean     100000 non-null  float64
#  46  callfwdv_Mean     100000 non-null  float64
#  47  callwait_Mean     100000 non-null  float64
#  48  churn             100000 non-null  int64
#  49  months            100000 non-null  int64
#  50  uniqsubs          100000 non-null  int64
#  51  actvsubs          100000 non-null  int64
#  52  new_cell          100000 non-null  object
#  53  crclscod          100000 non-null  object
#  54  asl_flag          100000 non-null  object
#  55  totcalls          100000 non-null  int64
#  56  totmou            100000 non-null  float64
#  57  totrev            100000 non-null  float64
#  58  adjrev            100000 non-null  float64
#  59  adjmou            100000 non-null  float64
#  60  adjqty            100000 non-null  int64
#  61  avgrev            100000 non-null  float64
#  62  avgmou            100000 non-null  float64
#  63  avgqty            100000 non-null  float64
#  64  avg3mou           100000 non-null  int64
#  65  avg3qty           100000 non-null  int64
#  66  avg3rev           100000 non-null  int64
#  67  avg6mou           97161 non-null   float64
#  68  avg6qty           97161 non-null   float64
#  69  avg6rev           97161 non-null   float64
#  70  prizm_social_one  92612 non-null   object
#  71  area              99960 non-null   object
#  72  dualband          99999 non-null   object
#  73  refurb_new        99999 non-null   object
#  74  hnd_price         99153 non-null   float64
#  75  phones            99999 non-null   float64
#  76  models            99999 non-null   float64
#  77  hnd_webcap        89811 non-null   object
#  78  truck             98268 non-null   float64
#  79  rv                98268 non-null   float64
#  80  ownrent           66294 non-null   object
#  81  lor               69810 non-null   float64
#  82  dwlltype          68091 non-null   object
#  83  marital           98268 non-null   object
#  84  adults            76981 non-null   float64
#  85  infobase          77921 non-null   object
#  86  income            74564 non-null   float64
#  87  numbcars          50634 non-null   float64
#  88  HHstatin          62077 non-null   object
#  89  dwllsize          61692 non-null   object
#  90  forgntvl          98268 non-null   float64
#  91  ethnic            98268 non-null   object
#  92  kid0_2            98268 non-null   object
#  93  kid3_5            98268 non-null   object
#  94  kid6_10           98268 non-null   object
#  95  kid11_15          98268 non-null   object
#  96  kid16_17          98268 non-null   object
#  97  creditcd          98268 non-null   object
#  98  eqpdays           99999 non-null   float64
#  99  Customer_ID       100000 non-null  int64
# dtypes: float64(69), int64(10), object(21)
# memory usage: 76.3+ MB

# %%
df.describe()
# Out:
#            rev_Mean      mou_Mean   totmrc_Mean       da_Mean   ovrmou_Mean  \
# count  99643.000000  99643.000000  99643.000000  99643.000000  99643.000000
# mean      58.719985    513.559937     46.179136      0.888828     41.072247
# std       46.291677    525.168140     23.623489      2.177619     97.296150
# min       -6.167500      0.000000    -26.915000      0.000000      0.000000
# 25%       33.260000    150.750000     30.000000      0.000000      0.000000
# 50%       48.195000    355.500000     44.990000      0.247500      2.750000
# 75%       70.750000    703.000000     59.990000      0.990000     42.000000
# max     3843.262500  12206.750000    409.990000    159.390000   4320.750000
#
#         ovrrev_Mean   vceovr_Mean   datovr_Mean     roam_Mean    change_mou  \
# count  99643.000000  99643.000000  99643.000000  99643.000000  99109.000000
# mean      13.559560     13.295062      0.261318      1.286405    -13.933818
# std       30.500885     30.056089      3.126531     14.711374    276.087509
# min        0.000000      0.000000      0.000000      0.000000  -3875.000000
# 25%        0.000000      0.000000      0.000000      0.000000    -87.000000
# 50%        1.000000      0.682500      0.000000      0.000000     -6.250000
# 75%       14.437500     14.025000      0.000000      0.235000     63.000000
# max     1102.400000    896.087500    423.540000   3685.200000  31219.250000
#
#        ...        models         truck            rv           lor  \
# count  ...  99999.000000  98268.000000  98268.000000  69810.000000
# mean   ...      1.545825      0.188820      0.082580      6.177238
# std    ...      0.898395      0.391368      0.275248      4.735267
# min    ...      1.000000      0.000000      0.000000      0.000000
# 25%    ...      1.000000      0.000000      0.000000      2.000000
# 50%    ...      1.000000      0.000000      0.000000      5.000000
# 75%    ...      2.000000      0.000000      0.000000      9.000000
# max    ...     16.000000      1.000000      1.000000     15.000000
#
#              adults        income      numbcars      forgntvl       eqpdays  \
# count  76981.000000  74564.000000  50634.000000  98268.000000  99999.000000
# mean       2.530326      5.783112      1.567563      0.057974    391.932309
# std        1.452819      2.182132      0.625456      0.233696    256.482193
# min        1.000000      1.000000      1.000000      0.000000     -5.000000
# 25%        1.000000      4.000000      1.000000      0.000000    212.000000
# 50%        2.000000      6.000000      1.000000      0.000000    342.000000
# 75%        3.000000      7.000000      2.000000      0.000000    530.000000
# max        6.000000      9.000000      3.000000      1.000000   1823.000000
#
#         Customer_ID
# count  1.000000e+05
# mean   1.050000e+06
# std    2.886766e+04
# min    1.000001e+06
# 25%    1.025001e+06
# 50%    1.050000e+06
# 75%    1.075000e+06
# max    1.100000e+06
#
# [8 rows x 79 columns]

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Outliers:</b> Negative values for some columns, e.g. Mean total monthly recurring charge.
# </div>

# %%
columns_df = pd.read_excel('Dictionary.xlsx')
columns_df.head()
# Out:
#        feature                              description
# 0     rev_Mean     Mean monthly revenue (charge amount)
# 1     mou_Mean    Mean number of monthly minutes of use
# 2  totmrc_Mean      Mean total monthly recurring charge
# 3      da_Mean  Mean number of directory assisted calls
# 4  ovrmou_Mean              Mean overage minutes of use

# %%
columns_dict = {}
for k, v in zip(columns_df['feature'], columns_df['description']):
    columns_dict[k] = v
# columns_dict = dict(columns_df['feature']:columns_df['description'])

# %%
df.isnull().sum().sort_values(ascending = False)
# Out:
# numbcars         49366
# dwllsize         38308
# HHstatin         37923
# ownrent          33706
# dwlltype         31909
#                  ...
# opk_vce_Mean         0
# mou_pead_Mean        0
# mou_peav_Mean        0
# peak_dat_Mean        0
# months               0
# Length: 100, dtype: int64

# %%
columns_dict['totmrc_Mean']
# Out:
# 'Mean total monthly recurring charge'

# %%
# Returns the appropriate size of plots grid depending on the number of plots
def plot_grid(f):
    h = int(np.sqrt(f))
    k = int(f/h)
    if k*h < f:
        if k > h:
            h+=1
        else:
            k +=1
    return k,h

# %%
# Create plots in a grid for initial data exploration purposes
plot_features = ['rev_Mean','totmrc_Mean','change_mou','change_rev','blck_vce_Mean','custcare_Mean','ccrndmou_Mean','complete_Mean','months']
x_plots, y_plots = plot_grid(len(plot_features))
fig, axs = plt.subplots(x_plots,y_plots,figsize = (20,20))
feature_index = 0

for handle_x in range(x_plots):
    for handle_y in range(y_plots):
        feature = plot_features[feature_index]
        axs[handle_x,handle_y].hist(df[df['churn']==1][feature], range=(0,200), bins=50, alpha=0.5)
        axs[handle_x,handle_y].hist(df[df['churn']==0][feature], range=(0,200), bins=50, alpha=0.5)
        axs[handle_x,handle_y].set_title(columns_dict[feature])
        axs[handle_x,handle_y].legend(['Churn', 'Non-Churn'])
        feature_index += 1

plt.show()

# %% [markdown]
# ### Takeaway 0
# As seen in the histograms above, features behave mostly similarly in terms of frequency, which makes coming up with new derivative features a must.

# %%
features = ['mou_cvce_Mean','ovrrev_Mean','ccrndmou_Mean','hnd_price','months']#'change_mou','adjrev','adjmou','adjqty','avgrev','avgmou','avgqty','avg3mou','avg3qty','avg3rev','avg6mou','avg6qty','avg6rev']
labels = []
for f in features:
    labels.append(columns_dict[f])
    
churn_values = []
nonchurn_values = []
for f in features:
    churn_values.append(df[df['churn']==1][f].mean())
    nonchurn_values.append(df[df['churn']==0][f].mean())
    
x = np.arange(len(labels))  # the label locations
width = 0.35  # the width of the bars

fig, ax = plt.subplots(figsize = (15,10))
rects1 = ax.bar(x - width/2, churn_values, width, label='Churn')
rects2 = ax.bar(x + width/2, nonchurn_values, width, label='Non-Churn')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Average Values')
# ax.set_title('Scores by group and gender')
ax.set_xticks(x)
ax.set_xticklabels(labels, rotation=45)
ax.legend()

# ax.bar_label(rects1, padding=3)
# ax.bar_label(rects2, padding=3)

fig.tight_layout()

plt.show()

# %% [markdown]
# ### Takeaway 1-2
# The features in the bar plot above, except the last feature, have been chosen such that the difference between the mean values are the most among other features. For example, first figure tells that the first signal a subscriber gives before the churn is to talk less. This data is averaged over the last 3 months. Similarly, churn customers completed calls are significantly lower than non-churns.
# ### Takeaway 3
# Second figure tells that those who churn are paying more for overage than those who don't on average. This could be a sign that the customer's current plan do not fit his/her needs
# ### Takeaway 4
# One could expect for churn customers to talk to customer care services more. However, data suggests the other way around, which implies that those who touch base with the customer care are more likely to solve their problems and stay.
# ### Takeaway 5
# Customers with more expensive handsets are more likely to stay, which is worth further exploration.
# ### Takeaway 6
# Average amount of time that churn and nonchurn customers have been served has no significant difference, which suggests that the amount of time passed with a company do not have any effect on churn decision, i.e. low customer loyalty.
#
# --------------------------------
# <div class="alert alert-block alert-warning">
# These takeaways clearly show that the data in hand is worth working on and it is possible to acquire significant accuracies with the help of some feature engineering.
# </div>

# %% [markdown]
# ## Initial ML to understand the base
# Let us give it a try and train a simple model without doing any feature engineering (feature selection/aggregation etc).

# %%
df.isnull().sum().plot()
# Out:
# <AxesSubplot:>

# %%
# DROP the columns that has more than 5% null values
df_init = df.drop(df.columns[df.isnull().sum()>len(df)*0.05], axis = 1)

# %%
df_init.isnull().sum().max()
# Out:
# 2839

# %%
len(df_init.columns)
# Out:
# 89

# %%
# DROP the rows that has *any* null value
df_init.dropna(inplace = True)

# %%
len(df_init)
# Out:
# 93893

# %%
df_init.isnull().sum().sum()
# Out:
# 0

# %%
df_cat = df_init

# %%
# EXTRACT the numerical columns
numerics = ['int16', 'int32', 'int64', 'float16', 'float32', 'float64']
df_init = df_init.select_dtypes(include=numerics)

# %%
# Unique value frequency percentages for categorical columns
for column in df_init.columns:
    if len(df_cat[column].unique()) < 3:
        print(columns_dict[column], '-->', df_cat[column].unique())
        print(df_cat[column].value_counts(normalize=True) * 100)
        print('\n')
# Out:
# Instance of churn between 31-60 days after observation date --> [1 0]
# 0    50.245492
# 1    49.754508
# Name: churn, dtype: float64
#
#
# Truck indicator --> [0. 1.]
# 0.0    81.000714
# 1.0    18.999286
# Name: truck, dtype: float64
#
#
# RV indicator --> [0. 1.]
# 0.0    91.65646
# 1.0     8.34354
# Name: rv, dtype: float64
#
#
# Foreign travel dummy variable --> [0. 1.]
# 0.0    94.145463
# 1.0     5.854537
# Name: forgntvl, dtype: float64

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Correlation Analysis:</b> Correlation analysis between numerical-categorical and categorical-categorical is tricky, requires further attention
# </div>

# %%
fig = plt.figure(figsize=(30,30))
sns.heatmap(df_init.corr())
plt.show()

# %%
# CREATE THE CORRELATION MATRIX and filter with more than 90% correlation
df_init_corr = (np.abs(df_init.corr())>0.9) & (np.abs(df_init.corr())<1)

# %%
# CREATE the set that has names of highly correlated columns
corr_set = set()
for column in df_init_corr:
    if len(df_init_corr[column][df_init_corr[column]==True]) >0:
#         print(columns_dict[column], '  ',df_init_corr[column][df_init_corr[column]==True].index)
        for item in df_init_corr[column][df_init_corr[column]==True].index:
            corr_set.add(item)
#     corr_dict[column] = df_init_corr[column][df_init_corr[column]==True].index

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import cross_val_score,cross_val_predict
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import confusion_matrix,classification_report, accuracy_score
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# ### First create a model using all the numerical columns without removing anything

# %%
# remove the Cutomer_ID column as it is a random number assigned to every customer
y = df_init['churn']
X = df_init.drop(['churn', 'Customer_ID'], axis=1)

# %%
# standardize the values to help models converge easily
scaler = StandardScaler()
X = pd.DataFrame(scaler.fit_transform(X))

# %%
X.head()
# Out:
#          0         1         2         3         4         5        6   \
# 0 -0.747421 -0.555216 -1.006456 -0.293339 -0.421292 -0.441703 -0.43964
# 1 -0.899559 -0.956448 -1.241561 -0.408574 -0.421292 -0.441703 -0.43964
# 2 -0.443417 -0.961728 -0.345091 -0.408574 -0.421292 -0.441703 -0.43964
# 3 -0.069342  0.119104  1.104792 -0.408574 -0.421292 -0.441703 -0.43964
# 4  0.517824  1.543096  1.233652  0.167601 -0.421292 -0.441703 -0.43964
#
#          7         8         9   ...        63        64        65        66  \
# 0 -0.080969 -0.084678 -0.523461  ... -0.375061 -0.228517 -0.505804  0.799693
# 1 -0.080969 -0.084678  0.036865  ... -1.004279 -0.944275 -1.025702 -1.166296
# 2 -0.080969 -0.084678  0.046936  ... -0.925373 -0.839665 -0.456290 -1.166296
# 3 -0.080969 -0.084678  0.193426  ...  0.159065  0.101833  0.533992  0.799693
# 4 -0.080969 -0.084678  0.626489  ...  1.375012  3.719168  0.484478  0.472028
#
#          67        68        69        70        71        72
# 0  0.156322  0.499952 -0.484311 -0.301713 -0.249371 -0.149970
# 1  0.156322 -0.610208 -0.484311 -0.301713 -0.249371  4.336906
# 2 -0.601269 -0.610208 -0.484311 -0.301713 -0.249371  5.545968
# 3  3.186689  2.720272 -0.484311 -0.301713 -0.249371  0.136593
# 4  5.459463  2.720272 -0.484311 -0.301713 -0.249371  0.230806
#
# [5 rows x 73 columns]

# %% [markdown]
# ### Begin trying LOGISTIC REGRESSION

# %%
lr=LogisticRegression(solver="lbfgs", max_iter=1000, random_state=2)

y_pred = cross_val_predict(lr,X, y, cv=5)

# %%
print('Accuracy Score:  ', accuracy_score(y,y_pred).round(2))
print(confusion_matrix(y, y_pred))
print('\n',classification_report(y,y_pred))
# Out:
# Accuracy Score:   0.58
# [[27442 19735]
#  [19897 26819]]
#
#                precision    recall  f1-score   support
#
#            0       0.58      0.58      0.58     47177
#            1       0.58      0.57      0.58     46716
#
#     accuracy                           0.58     93893
#    macro avg       0.58      0.58      0.58     93893
# weighted avg       0.58      0.58      0.58     93893

# %%
# Half of the set CHURNS, dataset is BALANCED
round((1 - sum(df_init['churn']==1)/len(df_init)),3)
# Out:
# 0.502

# %% [markdown]
# #### Let's remove correlated columns and try again LOGISTIC REGRESSION

# %%
df_init_corr = df_init.drop(corr_set, axis = 1)

# %%
df_init_corr.columns
# Out:
# Index(['totmrc_Mean', 'da_Mean', 'datovr_Mean', 'roam_Mean', 'change_mou',
#        'change_rev', 'drop_vce_Mean', 'drop_dat_Mean', 'blck_vce_Mean',
#        'blck_dat_Mean', 'unan_vce_Mean', 'unan_dat_Mean', 'recv_sms_Mean',
#        'custcare_Mean', 'threeway_Mean', 'mou_cvce_Mean', 'mou_rvce_Mean',
#        'owylis_vce_Mean', 'mouowylisv_Mean', 'iwylis_vce_Mean',
#        'mouiwylisv_Mean', 'mou_peav_Mean', 'mou_pead_Mean', 'opk_vce_Mean',
#        'mou_opkv_Mean', 'drop_blk_Mean', 'callfwdv_Mean', 'callwait_Mean',
#        'churn', 'months', 'uniqsubs', 'actvsubs', 'avgrev', 'hnd_price',
#        'phones', 'models', 'truck', 'rv', 'forgntvl', 'eqpdays',
#        'Customer_ID'],
#       dtype='object')

# %%
y_corr = df_init_corr['churn']
X_corr = df_init_corr.drop(['churn', 'Customer_ID'], axis=1)
scaler = StandardScaler()
X_corr = pd.DataFrame(scaler.fit_transform(X_corr))

# %%
lr_corr=LogisticRegression(solver="lbfgs", max_iter=1000, random_state=2)
y_pred_corr = cross_val_predict(lr_corr,X_corr, y_corr, cv=5)

# %%
print('Accuracy Score:  ', accuracy_score(y_corr,y_pred_corr).round(2))
print(confusion_matrix(y_corr, y_pred_corr))
print('\n',classification_report(y_corr,y_pred_corr))
# Out:
# Accuracy Score:   0.57
# [[27340 19837]
#  [20460 26256]]
#
#                precision    recall  f1-score   support
#
#            0       0.57      0.58      0.58     47177
#            1       0.57      0.56      0.57     46716
#
#     accuracy                           0.57     93893
#    macro avg       0.57      0.57      0.57     93893
# weighted avg       0.57      0.57      0.57     93893

# %% [markdown]
# #### We used only the numerical columns ready and no categorical columns. We dealt with the null values roughly. Logistic regression gives only a ***7%*** improvement. Not a good job actually!
#
# Now let a tree classifier decide which columns are important

# %%
from sklearn.ensemble import ExtraTreesClassifier

# %%
model = ExtraTreesClassifier(n_estimators=20)
model.fit(X_corr, y_corr)
print(model.feature_importances_)
# Out:
# [0.04019133 0.03236975 0.01558223 0.02931893 0.04436767 0.04037751
#  0.03269778 0.0041888  0.03067786 0.00225612 0.03329542 0.00532824
#  0.00217085 0.0269599  0.0211442  0.03459974 0.03297159 0.03221298
#  0.03163501 0.02918193 0.02897111 0.0340413  0.01017763 0.03390771
#  0.03412817 0.03189262 0.00133555 0.02528754 0.04797538 0.02116794
#  0.01580789 0.04306546 0.0337885  0.02067727 0.01612216 0.00939689
#  0.00601037 0.00667755 0.05804108]

# %%
feature_importances = pd.Series(model.feature_importances_)
feature_importances.plot()
# Out:
# <AxesSubplot:>

# %%
feature_importances.describe()
# Out:
# count    39.000000
# mean      0.025641
# std       0.014088
# min       0.001336
# 25%       0.015695
# 50%       0.029319
# 75%       0.033848
# max       0.058041
# dtype: float64

# %%
features_cust = feature_importances[feature_importances >=0.02].index

# %%
lr=LogisticRegression(solver="lbfgs", max_iter=1000, random_state=2)

scores = cross_val_score(lr,X[features_cust], y, cv=5)
scores.mean()
# Out:
# 0.5448008235847823

# %% [markdown]
# #### EVEN WORSE!

# %% [markdown]
# ## LET'S START WORKING ON THE CATEGORICAL COLUMNS

# %%
df_cat = df_cat.select_dtypes(exclude=numerics)
df_cat['churn'] = df_init['churn']

# %%
df_cat.head()
# Out:
#   new_cell crclscod asl_flag                           area dualband  \
# 0        U        A        N  NORTHWEST/ROCKY MOUNTAIN AREA        Y
# 2        Y        C        N               GREAT LAKES AREA        N
# 3        Y        B        N                   CHICAGO AREA        N
# 4        Y        A        N               NEW ENGLAND AREA        Y
# 5        Y        C        N               GREAT LAKES AREA        N
#
#   refurb_new marital ethnic kid0_2 kid3_5 kid6_10 kid11_15 kid16_17 creditcd  \
# 0          N       S      N      U      U       U        U        U        Y
# 2          N       M      N      U      Y       U        U        U        Y
# 3          N       M      U      Y      U       U        U        U        Y
# 4          N       S      I      U      U       U        U        U        Y
# 5          N       S      U      U      U       U        U        U        Y
#
#    churn
# 0      1
# 2      1
# 3      0
# 4      0
# 5      0

# %%
# Unique value frequency percentages for categorical columns
for column in df_cat.columns:
    print(columns_dict[column], '-->', df_cat[column].unique())
    print(df_cat[column].value_counts(normalize=True) * 100)
    print('\n')
# Out:
# New cell phone user --> ['U' 'Y' 'N']
# U    66.423482
# Y    19.570149
# N    14.006369
# Name: new_cell, dtype: float64
#
#
# Credit class code --> ['A' 'C' 'B' 'BA' 'D' 'G' 'CA' 'AA' 'U' 'Z' 'E' 'EA' 'J' 'E4' 'W' 'DA' 'Y'
#  'CC' 'GA' 'D4' 'D5' 'H' 'ZA' 'JF' 'K' 'B2' 'Z1' 'O' 'M' 'U1' 'Z4' 'A2'
#  'V' 'I' 'TP' 'EM' 'C2' 'C5' 'Z5' 'D2' 'GY' 'ZY' 'E2' 'A3' 'V1' 'Z2' 'CY'
#  'EC' 'P1' 'IF' 'ZF' 'EF' 'L']
# AA    36.992108
# A     17.439000
# BA    12.588798
# CA     8.272182
# EA     6.342326
# B      4.212242
# DA     3.619013
# ZA     3.483753
# C      1.507035
# A2     0.853099
# E4     0.716773
# U      0.475009
# E      0.347204
# GA     0.270521
# D4     0.266261
# D      0.246025
# G      0.244960
# Z4     0.201293
# JF     0.199163
# Z      0.190643
# CY     0.182122
# M      0.172537
# C2     0.169342
# ZY     0.111829
# I      0.107569
# D5     0.097984
# W      0.096919
# C5     0.072423
# U1     0.067098
# B2     0.057512
# EM     0.055382
# Z5     0.047927
# V1     0.045797
# EC     0.038342
# GY     0.033016
# J      0.027691
# O      0.024496
# CC     0.023431
# E2     0.022366
# K      0.015976
# Y      0.011715
# Z1     0.011715
# H      0.008520
# TP     0.005325
# D2     0.005325
# Z2     0.005325
# IF     0.003195
# A3     0.003195
# P1     0.003195
# EF     0.002130
# V      0.001065
# ZF     0.001065
# L      0.001065
# Name: crclscod, dtype: float64
#
#
# Account spending limit --> ['N' 'Y']
# N    86.830754
# Y    13.169246
# Name: asl_flag, dtype: float64
#
#
# Geogrpahic area --> ['NORTHWEST/ROCKY MOUNTAIN AREA' 'GREAT LAKES AREA' 'CHICAGO AREA'
#  'NEW ENGLAND AREA' 'DALLAS AREA' 'CENTRAL/SOUTH TEXAS AREA'
#  'TENNESSEE AREA' 'MIDWEST AREA' 'PHILADELPHIA AREA' 'OHIO AREA'
#  'HOUSTON AREA' 'SOUTHWEST AREA' 'NEW YORK CITY AREA'
#  'ATLANTIC SOUTH AREA' 'SOUTH FLORIDA AREA' 'CALIFORNIA NORTH AREA'
#  'DC/MARYLAND/VIRGINIA AREA' 'NORTH FLORIDA AREA' 'LOS ANGELES AREA']
# NEW YORK CITY AREA               11.232999
# DC/MARYLAND/VIRGINIA AREA         6.527643
# LOS ANGELES AREA                  6.478651
# MIDWEST AREA                      6.381732
# SOUTHWEST AREA                    6.113342
# ATLANTIC SOUTH AREA               6.090976
# CALIFORNIA NORTH AREA             5.995122
# DALLAS AREA                       5.489227
# NEW ENGLAND AREA                  5.487097
# CHICAGO AREA                      5.164389
# GREAT LAKES AREA                  4.684055
# OHIO AREA                         4.612697
# NORTHWEST/ROCKY MOUNTAIN AREA     4.335786
# NORTH FLORIDA AREA                4.326201
# CENTRAL/SOUTH TEXAS AREA          4.274014
# HOUSTON AREA                      4.228217
# SOUTH FLORIDA AREA                3.359143
# TENNESSEE AREA                    2.748874
# PHILADELPHIA AREA                 2.469833
# Name: area, dtype: float64
#
#
# Dualband --> ['Y' 'N' 'T']
# Y    73.025678
# N    22.798292
# T     4.176030
# Name: dualband, dtype: float64
#
#
# Handset: refurbished or new --> ['N' 'R']
# N    85.341825
# R    14.658175
# Name: refurb_new, dtype: float64
#
#
# Marital Status --> ['S' 'M' 'A' 'U' 'B']
# U    37.699296
# M    31.764881
# S    18.029033
# B     7.244417
# A     5.262373
# Name: marital, dtype: float64
#
#
# Ethnicity roll-up code --> ['N' 'U' 'I' 'S' 'F' 'J' 'Z' 'M' 'H' 'G' 'D' 'O' 'R' 'B' 'P' 'X' 'C']
# N    34.038746
# H    13.859393
# S    13.014815
# U    11.145666
# G     6.047309
# Z     4.455071
# O     4.331526
# I     3.903379
# J     2.893719
# F     2.154580
# B     1.400530
# R     1.063977
# D     0.887180
# P     0.396196
# C     0.186382
# M     0.154431
# X     0.067098
# Name: ethnic, dtype: float64
#
#
# Child 0 - 2 years of age in household --> ['U' 'Y']
# U    95.886807
# Y     4.113193
# Name: kid0_2, dtype: float64
#
#
# Child 3 - 5 years of age in household --> ['U' 'Y']
# U    95.212636
# Y     4.787364
# Name: kid3_5, dtype: float64
#
#
# Child 6 - 10 years of age in household --> ['U' 'Y']
# U    91.744859
# Y     8.255141
# Name: kid6_10, dtype: float64
#
#
# Child 11 - 15 years of age in household --> ['U' 'Y']
# U    91.028085
# Y     8.971915
# Name: kid11_15, dtype: float64
#
#
# Child 16 - 17 years of age in household --> ['U' 'Y']
# U    89.843758
# Y    10.156242
# Name: kid16_17, dtype: float64
#
#
# Credit card indicator --> ['Y' 'N']
# Y    68.89864
# N    31.10136
# Name: creditcd, dtype: float64
#
#
# Instance of churn between 31-60 days after observation date --> [1 0]
# 0    50.245492
# 1    49.754508
# Name: churn, dtype: float64

# %%
# Create plots in a grid for initial data exploration purposes
plot_features = list(df_cat.columns)
plot_features.remove('churn')
# x_plots, y_plots = plot_grid(len(plot_features))
fig, axs = plt.subplots(len(plot_features),1,figsize = (20,50))
fig_index = 0
tot = len(df_cat)
width = 0.35
for feature in plot_features:
    x = np.arange(len(df_cat[feature].unique()))
    vals = df_cat[feature].value_counts().index
    churn_values = []
    nonchurn_values = []
    
    for unique_val in vals:
        
        if unique_val in df_cat[feature][df_cat['churn']==1].value_counts(normalize=True).index:
            churn_value = df_cat[feature][df_cat['churn']==1].value_counts(normalize=True).loc[unique_val]*100
        else:
            churn_value = 0
            
        if unique_val in df_cat[feature][df_cat['churn']==0].value_counts(normalize=True).index:
            nonchurn_value = df_cat[feature][df_cat['churn']==0].value_counts(normalize=True).loc[unique_val]*100
        else:
            nonchurn_value = 0
        churn_values.append(churn_value)
        nonchurn_values.append(nonchurn_value)
            
    rects1 = axs[fig_index].bar(x - width/2, churn_values, width, label='Churn')
    rects2 = axs[fig_index].bar(x + width/2, nonchurn_values, width, label='Non-Churn')
    axs[fig_index].set_xticks(x)
    axs[fig_index].set_xticklabels(vals)
    axs[fig_index].legend()
    axs[fig_index].set_title(columns_dict[feature])
    fig_index += 1

plt.show()

# %% [markdown]
# ### Feature Engineering for Categorical Data
#
# * New cell phone user: get_dummies
# * Credit class code: Group into subcategories, i.e. Excellent, Good, Average, Poor
# * Account spending limit: get_dummies
# * Geogrpahic area: Could be grouped into subcategories, i.e. east, west etc, DISCARD FOR NOW
# * Dualband : get_dummies
# * Handset: get_dummies
# * Marital Status: get_dummies
# * Ethnicity roll-up code: doesn't seem relevant, will check
# * ALL child columns: doesn't seem relevant, will check
# * Credit card indicator: get dummies

# %% [markdown]
# ## Next Steps

# %% [markdown]
# 1. Outliers
# 2. Null values
# 3. Feature engineering on categorical data
# 4. Correlation analysis between numerical-categorical and categorical-categorical
# 5. Metric Selection

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Evaluation Metric:</b> Recall should be chosen as predicting the customers that are actually CHURNs is the most important. Recall = TP/(TP+FN)
# </div>

# %% [markdown]
# 6. Model Selection and Tuning
# 7. Presentation of results
